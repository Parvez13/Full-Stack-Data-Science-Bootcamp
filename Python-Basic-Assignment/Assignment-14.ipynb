# %% [markdown]
# ## Assignment-14

# %% [markdown]
# ## 1. What does RGBA stand for?
# * `R`: Read
# * `G`: Green
# * `B`: Blue
# * `A`: Alpha

# %% [markdown]
# ### 2. From the Pillow module, how do you get the RGBA value of any images?

# %%
# !pip install pillow
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\users\prvzs\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
from PIL import Image
img = Image.open('puppy.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x195 at 0x1CFB5147E20>

# %%
pixels = img.convert('RGBA')
data = img.getdata()
pixel_values = []
for pixel in data:
    pixel_values.append(pixel)

# %%
pixel_values
# Out:
# [(247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
#  (247, 247, 247),
# ...

# %% [markdown]
# ### 3. What is a box tuple, and how does it work?
# Box tuple is container of tuple of four integers where x-coordinate is represented by left edge, y-coordinate by top
# edge width and height respectively.

# %% [markdown]
# ### 4. Use your image and load in notebook then, How can you find out the width and height of an Image object?

# %%
puppy_image = Image.open('puppy.jpg')
image_width = puppy_image.width
image_height = puppy_image.height

print(f"Width : {image_width}, Height: {image_height}")
puppy_image
# Out:
# Width : 259, Height: 195
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x195 at 0x1CFB501B370>

# %% [markdown]
# ### 5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?

# %%
puppy_image2 = Image.open('puppy.jpg')
# puppy = puppy_image2.crop((0,50,50,50))
# puppy.show();
width, height = puppy_image2.size
 
left = 30
top = 50
right = 50
bottom = 50
# Cropped image of above dimension
# (It will not change original image)
crop_image = puppy_image2.crop((left,top, right, bottom))
crop_image.show()

# %% [markdown]
# ### 6. After making changes to an Image object, how could you save it as an image file?
# `crop_image.save('my_cropped_image.png')`

# %% [markdown]
# ### 7. What module contains Pillow’s shape-drawing code?
# * `ImageDraw()` Module

# %%
from PIL import ImageDraw

# %% [markdown]
# ### 8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?
# * They have shape drawing methods like line(), point(), rectangle()
# * We can call they by using ImageDraw.Draw() function.
